# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("fires.csv")
df.head()
# Out:
#       call_no  incident_type        type_description  \
# 0  F160029985          111.0           Building fire
# 1  F180022058          111.0           Building fire
# 2  F180022102          131.0  Passenger vehicle fire
# 3  F170043431          131.0  Passenger vehicle fire
# 4  F180021111          111.0           Building fire
#
#                                           address           alarm_time  \
# 0       800 BLOCK CENTER ST, WILKINSBURG PA 15221  2016-04-21T05:01:04
# 1        1100 BLOCK JANE ST, WILKINSBURG PA 15221  2018-03-13T08:34:43
# 2  SB STATE HWY 28 SB AT 31S, PITTSBURGH PA 15212  2018-03-13T11:54:23
# 3      1700 BLOCK BELLEAU DR, PITTSBURGH PA 15212  2017-05-31T08:39:47
# 4      2400 BLOCK VILLAGE RD, PITTSBURGH PA 15205  2018-03-09T10:26:42
#
#    alarms primary_unit  census_tract neighborhood  council_district  ward  \
# 0       1      231EN16           NaN          NaN               NaN   NaN
# ...

# %%
display(df.isnull().sum())
# Out:
# call_no                     0
# incident_type              18
# type_description            0
# address                     0
# alarm_time                 18
# alarms                      0
# primary_unit                4
# census_tract              518
# neighborhood             1074
# council_district         1051
# ward                     1076
# tract                     591
# public_works_division    1074
# pli_division             1076
# police_zone              1076
# fire_zone                   4
# latitude                  656
# longitude                 656
# dtype: int64

# %%
df1 = df.dropna()
print(df1)
# Out:
#          call_no  incident_type                        type_description  \
# 3     F170043431          131.0                  Passenger vehicle fire
# 4     F180021111          111.0                           Building fire
# 5     F180021782          150.0             Outside rubbish fire, Other
# 6     F180022495          113.0     Cooking fire, confined to container
# 7     F180022546          111.0                           Building fire
# ...          ...            ...                                     ...
# 8183  F210083435          131.0                  Passenger vehicle fire
# 8184  F210083732          111.0                           Building fire
# 8185  F210084457          111.0                           Building fire
# 8186  F210083809          113.0     Cooking fire, confined to container
# 8187  F210084813          173.0  Cultivated trees or nursery stock fire
#
#                                              address           alarm_time  \
# ...

# %%
df1.to_csv('cleanFires.csv')
